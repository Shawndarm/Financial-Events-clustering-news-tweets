# %% [markdown]
# # Relevant Words Extraction

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.figure_factory as ff
import os
import sys

sys.path.append(os.path.abspath(os.path.join('..')))
from src.relevant_words_extraction import *

# %% [markdown]
# ### Loading the cleaned news data

# %%
clean_news_df = pd.read_csv('../data/for_models/clean_news_week_SVB.csv')

# %%
my_lexicon = [
    # Macroeconomics & Indicators
    "inflation", "deflation", "stagflation", "gdp", "cpi", "ppi", "recession", 
    "growth", "expansion", "unemployment", "employment", "payrolls", "deficit", 
    "surplus", "debt", "stimulus", "productivity", "spending", "consumer", "retail",

    # Central Banks & Policy
    "fed", "ecb", "boj", "boe", "rates", "interest", "hiking", "tightening", 
    "easing", "hawkish", "dovish", "quantitative", "tapering", "policy", 
    "reserve", "federal", "monetary", "fiscal", "yield", "curve", "basis", "points",

    # Banking & Crisis (SVB/Lehman style)
    "bank", "banking", "deposit", "withdrawal", "solvency", "insolvency", 
    "liquidity", "capital", "tier", "bailout", "default", "bankruptcy", "collapse", 
    "failure", "contagion", "stress", "leverage", "credit", "lending", "loan",
    "panic", "run", "rescue", "fdic", "regulator", "stress test", "bearish", "bullish",

    # Stock Markets & Assets
    "stocks", "equities", "shares", "bull", "bear", "market", "rally", "plunge", 
    "correction", "volatility", "vix", "index", "nasdaq", "dow", "sp500", 
    "derivative", "futures", "options", "swap", "etf", "commodity", "gold", "oil",

    # Corporate Finance & Earnings
    "earnings", "revenue", "profit", "loss", "ebitda", "guidance", "forecast", 
    "dividend", "buyback", "ipo", "merger", "acquisition", "takeover", 
    "restructuring", "layoff", "valuation", "quarterly", "margin", "outperform",

    # Geopolitics & Regulatory
    "brexit", "sanctions", "trade", "tariff", "war", "election", "regulation", 
    "sec", "compliance", "antitrust", "lawsuit", "settlement", "fraud"
]

# %% [markdown]
# ### Relevant Financial Words Extraction

# %%
# Words Extraction
keywords_data = extract_relevant_words_with_scores(clean_news_df, my_lexicon, top_n=10)

# Vizualisation
fig_keywords = plot_keywords_bar_chart(keywords_data)
fig_keywords.show()
